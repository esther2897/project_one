# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

beds_df=pd.read_csv("beds_17-20df.csv").dropna(how='any')
pop_df=pd.read_csv("homeless_pop17-20.csv").dropna(how='any')

# %%
beds_df
# Out:
#    State  Total Year-Round Beds 2020  Total Year-Round Beds 2019  \
# 0     AK                      1885.0                      1878.0
# 1     AL                      2913.0                      2701.0
# 2     AR                      1686.0                      1917.0
# 3     AZ                      6079.0                      6568.0
# 4     CA                     53265.0                     46306.0
# 5     CO                      8274.0                      8196.0
# 6     CT                      2600.0                      2697.0
# 7     DC                      6687.0                      6156.0
# 8     DE                      1026.0                      1014.0
# 9     FL                     17793.0                     18617.0
# 10    GA                      7413.0                      7600.0
# 11    GU                       145.0                       161.0
# 12    HI                      3384.0                      3121.0
# ...
