# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
PIT_2017 = pd.read_csv("datasets/2017-Gender-By-State.csv")
PIT_2017.head()
gender_seven = PIT_2017[["State","Overall Homeless - Female, 2017","Overall Homeless - Male, 2017","Overall Homeless - Transgender, 2017","Overall Homeless - Gender Non-Conforming, 2017"]]
gender_seven = gender_seven.replace(r'^\s*$', np.nan, regex=True)
gender_seven = gender_seven[["Overall Homeless - Female, 2017","Overall Homeless - Transgender, 2017","Overall Homeless - Male, 2017","Overall Homeless - Gender Non-Conforming, 2017"]].astype(float)
gender_seven = gender_seven.rename(columns={"Overall Homeless - Female, 2017": "Female", "Overall Homeless - Transgender, 2017":"Transgender", "Overall Homeless - Male, 2017": "Male", "Overall Homeless - Gender Non-Conforming, 2017": "Gender Non-Conforming"})
gender_seven["State"] = PIT_2017["State"]
gender_seven = gender_seven.set_index("State")
sum_seven = gender_seven.loc["Total", :]
gender_seven_no_total = gender_seven.drop("Total")
colors = ['#ff9999','#99ff99','#66b3ff','#ffcc99']
gen_sev = gender_seven_no_total.plot.bar(stacked=True, title = 'Homeless Population in 2017, By Gender', color = {'Female': '#ff9999', 'Male': '#66b3ff', 'Transgender': 'green', 'Gender Non-Conforming': 'orange'})
gen_sev.set_xlabel("State")
gen_sev.set_ylabel("Number of Homeless People")
plt.savefig("gender_trends_by_state_2017.png")

# %%
PIT_2018 = pd.read_csv("datasets/2018-Gender-By-State.csv")
PIT_2018.head()
gender_eight = PIT_2018[["State","Overall Homeless - Female, 2018","Overall Homeless - Male, 2018","Overall Homeless - Transgender, 2018","Overall Homeless - Gender Non-Conforming, 2018"]]
gender_eight = gender_eight.replace(r'^\s*$', np.nan, regex=True)
gender_eight = gender_eight[["Overall Homeless - Female, 2018","Overall Homeless - Transgender, 2018","Overall Homeless - Male, 2018","Overall Homeless - Gender Non-Conforming, 2018"]].astype(float)
gender_eight.head()
gender_eight = gender_eight.rename(columns={"Overall Homeless - Female, 2018": "Female", "Overall Homeless - Transgender, 2018":"Transgender", "Overall Homeless - Male, 2018": "Male", "Overall Homeless - Gender Non-Conforming, 2018": "Gender Non-Conforming"})
gender_eight["State"] = PIT_2018["State"]
gender_eight = gender_eight.set_index("State")
sum_eight = gender_eight.loc["Total", :]
gender_eight_no_total = gender_eight.drop("Total")
gen_eig = gender_eight_no_total.plot.bar(stacked=True, title = 'Homeless Population in 2018, By Gender', color = {'Female': '#ff9999', 'Male': '#66b3ff', 'Transgender': 'green', 'Gender Non-Conforming': 'orange'})
gen_eig.set_xlabel("State")
gen_eig.set_ylabel("Number of Homeless People")
plt.savefig("gender_trends_by_state_2018.png")

# %%
PIT_2019 = pd.read_csv("datasets/2019-Gender-By-State.csv")
PIT_2019.head()
gender_nine = PIT_2019[["State","Overall Homeless - Female, 2019","Overall Homeless - Male, 2019","Overall Homeless - Transgender, 2019","Overall Homeless - Gender Non-Conforming, 2019"]]
gender_nine = gender_nine.replace(r'^\s*$', np.nan, regex=True)
gender_nine = gender_nine[["Overall Homeless - Female, 2019","Overall Homeless - Transgender, 2019","Overall Homeless - Male, 2019","Overall Homeless - Gender Non-Conforming, 2019"]].astype(float)
gender_nine.head()
gender_nine = gender_nine.rename(columns={"Overall Homeless - Female, 2019": "Female", "Overall Homeless - Transgender, 2019":"Transgender", "Overall Homeless - Male, 2019": "Male", "Overall Homeless - Gender Non-Conforming, 2019": "Gender Non-Conforming"})
gender_nine["State"] = PIT_2019["State"]
gender_nine = gender_nine.set_index("State")
sum_nine = gender_nine.loc["Total", :]
gender_nine_no_total = gender_nine.drop("Total")
gen_nin = gender_nine_no_total.plot.bar(stacked=True, title = 'Homeless Population in 2019, By Gender',color = {'Female': '#ff9999', 'Male': '#66b3ff', 'Transgender': 'green', 'Gender Non-Conforming': 'orange'})
gen_nin.set_xlabel("State")
gen_nin.set_ylabel("Number of Homeless People")
plt.savefig("gender_trends_by_state_2019.png")

# %%
PIT_2020 = pd.read_csv("datasets/2020-Gender-By-State.csv")
PIT_2020.head()
gender_twenty = PIT_2020[["State","Overall Homeless - Female, 2020","Overall Homeless - Male, 2020","Overall Homeless - Transgender, 2020","Overall Homeless - Gender Non-Conforming, 2020"]]
gender_twenty = gender_twenty.replace(r'^\s*$', np.nan, regex=True)
gender_twenty = gender_twenty[["Overall Homeless - Female, 2020","Overall Homeless - Transgender, 2020","Overall Homeless - Male, 2020","Overall Homeless - Gender Non-Conforming, 2020"]].astype(float)
gender_twenty = gender_twenty.rename(columns={"Overall Homeless - Female, 2020": "Female", "Overall Homeless - Transgender, 2020":"Transgender", "Overall Homeless - Male, 2020": "Male", "Overall Homeless - Gender Non-Conforming, 2020": "Gender Non-Conforming"})
gender_twenty["State"] = PIT_2020["State"]
gender_twenty = gender_twenty.set_index("State")
sum_twenty = gender_twenty.loc["Total", :]
gender_twenty_no_total = gender_twenty.drop("Total")
gen_twe = gender_twenty_no_total.plot.bar(stacked=True, title = 'Homeless Population in 2020, By Gender', color = {'Female': '#ff9999', 'Male': '#66b3ff', 'Transgender': 'green', 'Gender Non-Conforming': 'orange'})
gen_twe.set_xlabel("State")
gen_twe.set_ylabel("Number of Homeless People")
plt.savefig("gender_trends_by_state_2020.png")

# %%
years = ["2017", "2018", "2019", "2020"]
fem_through_years = [sum_seven["Female"],sum_eight["Female"], sum_nine["Female"], sum_twenty["Female"]]
men_through_years = [sum_seven["Male"],sum_eight["Male"], sum_nine["Male"], sum_twenty["Male"]]
trans_through_years = [sum_seven["Transgender"],sum_eight["Transgender"], sum_nine["Transgender"], sum_twenty["Transgender"]]
nonconform_through_years = [sum_seven["Gender Non-Conforming"],sum_eight["Gender Non-Conforming"], sum_nine["Gender Non-Conforming"], sum_twenty["Gender Non-Conforming"]]
gender_total_throughout_years = pd.DataFrame({'Female':fem_through_years, 'Male':men_through_years, 'Transgender':trans_through_years, 'Gender Non-Conforming': nonconform_through_years}, index=years)
gender_total_female_male = gender_total_throughout_years[["Female", "Male"]]
gender_total_f_m = gender_total_female_male.plot.line(color = {'Female': '#ff9999', 'Male': '#66b3ff'}, title = "Homeless Population from 2017 to 2020")
gender_total_f_m.set_xlabel("Years")
gender_total_f_m.set_ylabel("Number of Homeless People")
gender_total_f_m.grid()
plt.savefig("total_trend_female_male.png")

# %%
gender_total_trans_non = gender_total_throughout_years[["Transgender", "Gender Non-Conforming"]]
gender_total_t_g = gender_total_trans_non.plot.line(color = {'Transgender': 'green', 'Gender Non-Conforming': 'orange'}, title = "Homeless Population from 2017 to 2020")
gender_total_t_g.set_xlabel("Years")
gender_total_t_g.set_ylabel("Number of Homeless People")
gender_total_t_g.grid()
plt.savefig("total_trend_trans_gen_non_con.png")

# %%
new_index = ["Female", "Transgender", "Male", "Gender Non-conforming"]
sum_all = pd.DataFrame({'Distribution of Homeless Population By Gender, 2017':[sum_seven[0], sum_seven[1], sum_seven[2], sum_seven[3]], 'Distribution of Homeless Population By Gender, 2018':[sum_eight[0], sum_eight[1], sum_eight[2], sum_eight[3]], 'Distribution of Homeless Population By Gender, 2019':[sum_nine[0], sum_nine[1], sum_nine[2], sum_nine[3]], 'Distribution of Homeless Population By Gender, 2020':[sum_twenty[0], sum_twenty[1], sum_twenty[2], sum_twenty[3]]}, index = ["Female", "Transgender", "Male", "Gender Non-Conforming"])
explode = (0, 0.1, 0, 0)
colors = ['#ff9999','green','#66b3ff','yellow']
pie_all = sum_all.plot.pie(subplots=True, colors = colors, figsize=(35, 6), autopct="%1.1f%%", explode = explode, startangle=90, shadow = True)
plt.savefig("percent_gender_years.png")

# %%
sum_diff_seven = sum_all[['Distribution of Homeless Population By Gender, 2017']]


pie_diff = sum_diff_seven.plot.pie(subplots = True, colors = colors, figsize=(35, 6), autopct="%1.1f%%", explode = explode, startangle=90, shadow = True, )
plt.savefig("percent_gender_years_2017.png")

# %%
sum_diff_twenty = sum_all[['Distribution of Homeless Population By Gender, 2020']]


pie_diff_two = sum_diff_twenty.plot.pie(subplots = True, colors = colors, figsize=(35, 6), autopct="%1.1f%%", explode = explode, startangle=90, shadow = True)
plt.savefig("percent_gender_years_2020.png")

# %%
sum_all_edits = sum_all.rename(columns={'Distribution of Homeless Population By Gender, 2017':'2017', 'Distribution of Homeless Population By Gender, 2018':'2018', 'Distribution of Homeless Population By Gender, 2019':'2019','Distribution of Homeless Population By Gender, 2020':'2020'})
sum_all_transposed = sum_all_edits.transpose()
sum_stacked = sum_all_transposed.plot.bar(stacked=True, title = 'Homeless Population Throughout The Years, By Gender', color = {'Female': '#ff9999', 'Male': '#66b3ff', 'Transgender': 'green', 'Gender Non-Conforming': 'orange'})
sum_stacked.set_xlabel("Year")
sum_stacked.set_ylabel("Number of Homeless People")
sum_stacked.legend(loc='center left', bbox_to_anchor=(1, 0.5))
